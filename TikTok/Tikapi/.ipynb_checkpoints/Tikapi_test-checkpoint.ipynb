# %%
from tikapi import TikAPI, ValidationException, ResponseException

api = TikAPI("DemoAPIKeyTokenSeHYGXDfd4SFD320Sc39Asd0Sc39Asd4s")
api.set(
    __sandbox__=True
)

User = api.user(
    accountKey="DemoAccountKeyTokenSeHYGXDfd4SFD320Sc39Asd0Sc39A"
)

try:
    response = User.posts.comments.list(
        media_id="7109178205151464746"
    )

    response_json = response.json()
    print(response_json)
    i=0
    
    while(response):
        
        for comment in response_json['comments']:
            comment_text = comment['text']
            print(i,":",comment_text)
            i+=1 
        cursor = response.json().get('cursor')
        print("\nGetting next items, cursor value:", cursor,"\n")
        response = response.next_items()  #now gets only the first 20 comments again and again, maybe because we are using the sandbox...
        response_json = response.json()


except ValidationException as e:
    print(e, e.field)

except ResponseException as e:
    print(e, e.response.status_code)
# Out:
# {'alias_comment_deleted': False, 'comments': [{'author_pin': False, 'aweme_id': '7109178205151464746', 'cid': '7109185042560680750', 'collect_stat': 0, 'comment_language': 'en', 'create_time': 1655236182, 'digg_count': 8412, 'is_author_digged': False, 'label_list': None, 'no_show': False, 'reply_comment': None, 'reply_comment_total': 177, 'reply_id': '0', 'reply_to_reply_id': '0', 'share_info': {'acl': {'code': 1, 'extra': '{"item_share_acl":"empty item value"}'}, 'desc': "C's comment: man goes to Germany with a near unlimited budget and orders grilled cheese and chicken tenders", 'title': 'Gonna starve in Germany :(', 'url': 'https://m.tiktok.com/v/7109178205151464746.html?_d=e2d19ide73h5b4&comment_author_id=6797204664526980101&language=en&preview_pb=0&share_comment_id=7109185042560680750&share_item_id=7109178205151464746&source=h5_m&u_code=dd8i6568e8a8e8'}, 'status': 1, 'stick_position': 0, 'text': 'man goes to Germany with a near unlimited budget and orders grilled cheese and chicken tenders', 'text_extra': [], 'trans_btn_style': 0, 'user': {'ad_cover_url': None, 'advance_feature_item_order': None, 'advanced_feature_info': None, 'avatar_thumb': {'uri': 'tos-maliva-avt-0068/72d6fb527a7e5451501577d0ecdc3186', 'url_list': ['https://picsum.photos/seed/0xlMMP9yoDNuCP1mWDhim5Nuut4/500/500/', 'https://picsum.photos/seed/HKVSO1xzqkHUph0EQ5/500/500/', 'https://picsum.photos/seed/La/500/500/']}, 'bold_fields': None, 'can_set_geofencing': None, 'cha_list': None, 'cover_url': None, 'custom_verify': '', 'enterprise_verify_reason': '', 'events': None, 'followers_detail': None, 'geofencing': None, 'homepage_bottom_toast': None, 'item_list': None, 'mutual_relation_avatars': None, 'need_points': None, 'nickname': 'C', 'platform_sync_info': None, 'relative_users': None, 'search_highlight': None, 'sec_uid': 'MS4wLjABAAAAiBWkeHI69Bbf5gcs-nRrETGYZhBH9ajadCYNMS3j8fU_fRWnMbtE0ymP-VXnxt9z', 'type_label': None, 'uid': '6797204664526980101', 'unique_id': 'doowopdad', 'user_tags': None, 'white_cover_url': None}, 'user_buried': False, 'user_digged': 0}, {'author_pin': False, 'aweme_id': '7109178205151464746', 'cid': '7112068849369056046', 'collect_stat': 0, 'comment_language': 'en', 'create_time': 1655907580, 'digg_count': 164, 'is_author_digged': False, 'label_list': None, 'no_show': False, 'reply_comment': None, 'reply_comment_total': 0, 'reply_id': '0', 'reply_to_reply_id': '0', 'share_info': {'acl': {'code': 1, 'extra': '{"item_share_acl":"empty item value"}'}, 'desc': "Holly Scarfone's comment: Grilled cheese tar tar", 'title': 'Gonna starve in Germany :(', 'url': 'https://m.tiktok.com/v/7109178205151464746.html?_d=e2d19ide73h5b4&comment_author_id=6746345931446633478&language=en&preview_pb=0&share_comment_id=7112068849369056046&share_item_id=7109178205151464746&source=h5_m&u_code=dd8i6568e8a8e8'}, 'status': 1, 'stick_position': 0, 'text': 'Grilled cheese tar tar', 'text_extra': [], 'trans_btn_style': 0, 'user': {'ad_cover_url': None, 'advance_feature_item_order': None, 'advanced_feature_info': None, 'avatar_thumb': {'uri': 'tos-useast5-avt-0068-tx/1c3943484f79c57f47f185c193f280ab', 'url_list': ['https://picsum.photos/seed/oGc87/500/500/', 'https://picsum.photos/seed/28NQBg6X3WuOJtXe1EzyQ3MxKgM/500/500/', 'https://picsum.photos/seed/MLxVmveivRjGDOrkHtVBpcynVJw/500/500/']}, 'bold_fields': None, 'can_set_geofencing': None, 'cha_list': None, 'cover_url': None, 'custom_verify': 'Verified account', 'enterprise_verify_reason': '', 'events': None, 'followers_detail': None, 'geofencing': None, 'homepage_bottom_toast': None, 'item_list': None, 'mutual_relation_avatars': None, 'need_points': None, 'nickname': 'Holly Scarfone', 'platform_sync_info': None, 'relative_users': None, 'search_highlight': None, 'sec_uid': 'MS4wLjABAAAACWQfdqdFNFM2Jh66eF5tMnTEjGI5L2YdVibkj2T3NbzUuUXzyPVTLir3F4iqDarS', 'type_label': None, 'uid': '6746345931446633478', 'unique_id': 'hollyscarfone', 'user_tags': None, 'white_cover_url': None}, 'user_buried': False, 'user_digged': 0}, { ...
# 0 : man goes to Germany with a near unlimited budget and orders grilled cheese and chicken tenders
# 1 : Grilled cheese tar tar
# 2 : The real question is why are you in Germany ordering grilled cheese and chicken tenders
# 3 : Frankfurt food fr
# 4 : Uncooked grilled cheese is crazy
# 5 : Not the raw grilled cheese ð­â¼ï¸
# 6 : This the funniest thing yacht y has posted in like 5 years ð
# 7 : Bruh ððð
# 8 : Bro uncooked grilled cheese is crazy Fr ðððð
# 9 : The chicken tenders ðð­
# 10 : $40 for cold cheese is crazyyyð­
# 11 : its not even chicken tenders ð­ð­ that sh grilled tendersð­
# 12 : what even is that ð
# 13 : I thought this was play food ðð
# 14 : i love you boat
# 15 : hi yachty i love you
# 16 : LMAO
# 17 : Hell no, thatâs some shlt my grandma got from âmeals on wheelsâ
# 18 : ððHa Got-eeeemðð
# 19 : Nah I promise the food in Germany ainât that bad ð­ð­ð­
#
# Getting next items, cursor value: 20
# 20 : man goes to Germany with a near unlimited budget and orders grilled cheese and chicken tenders
# 21 : Grilled cheese tar tar
# 22 : The real question is why are you in Germany ordering grilled cheese and chicken tenders
# 23 : Frankfurt food fr
# 24 : Uncooked grilled cheese is crazy
# 25 : Not the raw grilled cheese ð­â¼ï¸
# 26 : This the funniest thing yacht y has posted in like 5 years ð
# 27 : Bruh ððð
# 28 : Bro uncooked grilled cheese is crazy Fr ðððð
# 29 : The chicken tenders ðð­
# 30 : $40 for cold cheese is crazyyyð­
# 31 : its not even chicken tenders ð­ð­ that sh grilled tendersð­
# 32 : what even is that ð
# 33 : I thought this was play food ðð
# 34 : i love you boat
# 35 : hi yachty i love you
# 36 : LMAO
# 37 : Hell no, thatâs some shlt my grandma got from âmeals on wheelsâ
# 38 : ððHa Got-eeeemðð
# 39 : Nah I promise the food in Germany ainât that bad ð­ð­ð­
#
# Getting next items, cursor value: 20
#
# 40 : man goes to Germany with a near unlimited budget and orders grilled cheese and chicken tenders
# 41 : Grilled cheese tar tar
# 42 : The real question is why are you in Germany ordering grilled cheese and chicken tenders
# 43 : Frankfurt food fr
# 44 : Uncooked grilled cheese is crazy
# 45 : Not the raw grilled cheese ð­â¼ï¸
# 46 : This the funniest thing yacht y has posted in like 5 years ð
# 47 : Bruh ððð
# 48 : Bro uncooked grilled cheese is crazy Fr ðððð
# 49 : The chicken tenders ðð­
# 50 : $40 for cold cheese is crazyyyð­
# 51 : its not even chicken tenders ð­ð­ that sh grilled tendersð­
# 52 : what even is that ð
# 53 : I thought this was play food ðð
# 54 : i love you boat
# 55 : hi yachty i love you
# 56 : LMAO
# 57 : Hell no, thatâs some shlt my grandma got from âmeals on wheelsâ
# 58 : ððHa Got-eeeemðð
# 59 : Nah I promise the food in Germany ainât that bad ð­ð­ð­
#
# Getting next items, cursor value: 20
#
# 60 : man goes to Germany with a near unlimited budget and orders grilled cheese and chicken tenders
# 61 : Grilled cheese tar tar
# 62 : The real question is why are you in Germany ordering grilled cheese and chicken tenders
# 63 : Frankfurt food fr
# 64 : Uncooked grilled cheese is crazy
# 65 : Not the raw grilled cheese ð­â¼ï¸
# 66 : This the funniest thing yacht y has posted in like 5 years ð
# 67 : Bruh ððð
# 68 : Bro uncooked grilled cheese is crazy Fr ðððð
# 69 : The chicken tenders ðð­
# 70 : $40 for cold cheese is crazyyyð­
# 71 : its not even chicken tenders ð­ð­ that sh grilled tendersð­
# 72 : what even is that ð
# 73 : I thought this was play food ðð
# 74 : i love you boat
# 75 : hi yachty i love you
# 76 : LMAO
# 77 : Hell no, thatâs some shlt my grandma got from âmeals on wheelsâ
# 78 : ððHa Got-eeeemðð
# 79 : Nah I promise the food in Germany ainât that bad ð­ð­ð­
#
# Getting next items, cursor value: 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 29
#      27         cursor = response.json().get('cursor')
#      28         print("\nGetting next items, cursor value:", cursor,"\n")
# ---> 29         response = response.next_items()  #now gets only the first 20 comments again and again, maybe because we are using the sandbox...
#      30         response_json = response.json()
#      33 except ValidationException as e:
#
# File ~/.local/lib/python3.8/site-packages/tikapi/__init__.py:64, in TikAPI.<locals>.on_success.<locals>.next_items()
#      61 else:
#      62 	return None
# ---> 64 return request.get('self')(**{
#      65 	**request.get('params', {}),
#      66 	**nextCursorParams
#      67 })
#
# File ~/.local/lib/python3.8/site-packages/tikapi/api.py:366, in Rests.<locals>.wrap.<locals>.process_request(**params)
#     363 	requests_kwargs['params'] = options['query']
#     365 try:
# --> 366 	response = make_request(url, options['method'], requests_kwargs)
#     367 	response.raise_for_status()
#     369 	if(callable(current_options.get('on_success'))):
#
# File ~/.local/lib/python3.8/site-packages/tikapi/api.py:91, in make_request(url, method, requests_kwargs)
#      90 def make_request(url, method, requests_kwargs) -> requests.Response:
# ---> 91 	return getattr(requests, method)(url, verify=False, **requests_kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 r"""Sends a GET request.
#      65
#      66 :param url: URL for the new :class:`Request` object.
#    (...)
#      71 :rtype: requests.Response
#      72 """
#      74 kwargs.setdefault('allow_redirects', True)
# ---> 75 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:60, in request(method, url, **kwargs)
#      56 # By using the 'with' statement we are sure the session is closed, thus we
#      57 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      58 # cases, and look like a memory leak in others.
#      59 with sessions.Session() as session:
# ---> 60     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:533, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528 send_kwargs = {
#     529     'timeout': timeout,
#     530     'allow_redirects': allow_redirects,
#     531 }
#     532 send_kwargs.update(settings)
# --> 533 resp = self.send(prep, **send_kwargs)
#     535 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:668, in Session.send(self, request, **kwargs)
#     665 gen = self.resolve_redirects(r, request, **kwargs)
#     667 # Resolve redirects if allowed.
# --> 668 history = [resp for resp in gen] if allow_redirects else []
#     670 # Shuffle things around if there's history.
#     671 if history:
#     672     # Insert the first (original) request at the start
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:668, in <listcomp>(.0)
#     665 gen = self.resolve_redirects(r, request, **kwargs)
#     667 # Resolve redirects if allowed.
# --> 668 history = [resp for resp in gen] if allow_redirects else []
#     670 # Shuffle things around if there's history.
#     671 if history:
#     672     # Insert the first (original) request at the start
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:239, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     236     yield req
#     237 else:
# --> 239     resp = self.send(
#     240         req,
#     241         stream=stream,
#     242         timeout=timeout,
#     243         verify=verify,
#     244         cert=cert,
#     245         proxies=proxies,
#     246         allow_redirects=False,
#     247         **adapter_kwargs
#     248     )
#     250     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     252     # extract redirect url, if any, for the next loop
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:646, in Session.send(self, request, **kwargs)
#     643 start = preferred_clock()
#     645 # Send the request
# --> 646 r = adapter.send(request, **kwargs)
#     648 # Total elapsed time of the request (approximately)
#     649 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:665, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     662     self._prepare_proxy(conn)
#     664 # Make the request on the httplib connection object.
# --> 665 httplib_response = self._make_request(
#     666     conn,
#     667     method,
#     668     url,
#     669     timeout=timeout_obj,
#     670     body=body,
#     671     headers=headers,
#     672     chunked=chunked,
#     673 )
#     675 # If we're going to release the connection in ``finally:``, then
#     676 # the response doesn't need to know about the connection. Otherwise
#     677 # it will also try to release it and we'll have a double-release
#     678 # mess.
#     679 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:421, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     416             httplib_response = conn.getresponse()
#     417         except BaseException as e:
#     418             # Remove the TypeError from the exception chain in
#     419             # Python 3 (including for exceptions like SystemExit).
#     420             # Otherwise it looks like a bug in the code.
# --> 421             six.raise_from(e, None)
#     422 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:416, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     413 except TypeError:
#     414     # Python 3
#     415     try:
# --> 416         httplib_response = conn.getresponse()
#     417     except BaseException as e:
#     418         # Remove the TypeError from the exception chain in
#     419         # Python 3 (including for exceptions like SystemExit).
#     420         # Otherwise it looks like a bug in the code.
#     421         six.raise_from(e, None)
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /usr/lib/python3/dist-packages/urllib3/contrib/pyopenssl.py:313, in WrappedSocket.recv_into(self, *args, **kwargs)
#     311 def recv_into(self, *args, **kwargs):
#     312     try:
# --> 313         return self.connection.recv_into(*args, **kwargs)
#     314     except OpenSSL.SSL.SysCallError as e:
#     315         if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# File /usr/lib/python3/dist-packages/OpenSSL/SSL.py:1821, in Connection.recv_into(self, buffer, nbytes, flags)
#    1819     result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820 else:
# -> 1821     result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822 self._raise_ssl_error(self._ssl, result)
#    1824 # This strange line is all to avoid a memory copy. The buffer protocol
#    1825 # should allow us to assign a CFFI buffer to the LHS of this line, but
#    1826 # on CPython 3.3+ that segfaults. As a workaround, we can temporarily
#    1827 # wrap it in a memoryview.
#
# KeyboardInterrupt:
