# %% [markdown]
# # Reading comment list for a video
#
# This script can read all the comments and their metadata for a list of TikTok videos.
# You have to specify the list of TikTok video ids in the video_ids_file vector (one line for each id).

# %%
from tikapi import TikAPI, ValidationException, ResponseException
import json
import glob

api = TikAPI("1jDHBpHXtsycrmEqK5AVvhvPZq3N2ZGeFNJKzYEJ2MHTPb4y")
User = api.user(accountKey="6EjyV4OptbvUz1cKgMTnvbXNH1wKPqLVV42jKlzydbVrFLnb")

output_file = "./data/comment_list.json"
video_ids_file = "./data/video_ids.txt"

max_requests_for_each_video = 3
number_of_comment_each_request = 30
j = 0 #single video request counter
total_n_comments_read = 0 #total comments counter

#read video ids from file
video_ids = []
with open(video_ids_file) as infile:
    video_ids = [line.rstrip() for line in infile]
print("video ids read:",video_ids)

result = [] #it will contain all the json responses for each request

for video_id in video_ids: #for each video
    print("\n\n#########################################\n\nProcessing video",video_id)
    try:
        response = User.posts.comments.list(
            media_id = video_id,
            count = number_of_comment_each_request # (max possible value is 30)
        )

        response_json = response.json()
        print(response_json)
        
        j=1
        while(response):    
            #append response data to result list
            result.append(response_json)

            #print comments of response data
            for comment in response_json['comments']:
                comment_text = comment['text']
                print(total_n_comments_read,":",comment_text)
                total_n_comments_read += 1 
                
            if j >= max_requests_for_each_video: #check if we reached maximum n of requests for this video
                break #stop
                
            #if not, do next request
            cursor = response.json().get('cursor')
            print("\nGetting next items, cursor value:", cursor,"\n")
            response = response.next_items()  
            response_json = response.json()
            j+=1

    except ValidationException as e:
        print(e, e.field)

    except ResponseException as e:
        print(e, e.response.status_code)
# Out:
# video ids read: ['7144246488879713542\n', '7144023384853171462']
#
#
# #########################################
#
# Processing video 7144246488879713542
#
# {'alias_comment_deleted': False, 'comments': [{'author_pin': False, 'aweme_id': '7144246488879713542', 'cid': '7144251353681347333', 'collect_stat': 0, 'comment_language': 'it', 'create_time': 1663400680, 'digg_count': 118, 'is_author_digged': False, 'label_list': None, 'no_show': False, 'reply_comment': None, 'reply_comment_total': 18, 'reply_id': '0', 'reply_to_reply_id': '0', 'share_info': {'acl': {'code': 1, 'extra': '{"item_share_acl":"empty item value"}'}, 'desc': "Giuseppina Aversa567's comment: forza conte 🥰", 'title': 'Sarò chiara ancora una volta: non c’è alcuna possibilità che #fratelliditalia  vada al Governo col Partito Democratico. Noi combattiamo la loro egemonia di potere e non saranno di certo le assurde ricostruzioni giornalistiche a farci cambiare idea.', 'url': 'https://m.tiktok.com/v/7144246488879713542.html?_d=e5c561b583004i&comment_author_id=6830525987130786822&language=en&preview_pb=0&share_comment_id=7144251353681347333&share_item_id=7144246488879713542&source=h5_m&u_code=e4kc6ej26a30kk'}, 'status': 1, 'stick_position': 0, 'text': 'forza conte 🥰', 'text_extra': [], 'trans_btn_style': 1, 'user': {'account_labels': None, 'ad_cover_url': None, 'advance_feature_item_order': None, 'advanced_feature_info': None, 'avatar_thumb': {'uri': 'tiktok-obj/1685238696695809', 'url_list': ['https://p16-sign-sg.tiktokcdn.com/aweme/100x100/tiktok-obj/1685238696695809.jpg?x-expires=1671368400&x-signature=uqVRYug8VP7xmazkZT0EjpLDbhY%3D', 'https://p77-sign-sg.tiktokcdn.com/aweme/100x100/tiktok-obj/1685238696695809.jpg?x-expires=1671368400&x-signature=kzh7SJzzN6CY%2FxXErWYojnWYDts%3D', 'https://p16-sign-sg.tiktokcdn.com/aweme/100x100/tiktok-obj/1685238696695809.jpeg?x-expires=1671368400&x-signature=9%2BnheheBCDtX9LVHzRUvlLlPjqQ%3D']}, 'bold_fields': None, 'can_message_follow_status_list': None, 'can_set_geofencing': None, 'cha_list': None, 'cover_url': None, 'custom_verify': '', 'enterprise_verify_reason': '', 'events': None, 'followers_detail': None, 'geofencing': None, 'homepage_bottom_toast': None, 'item_list': None, 'mutual_relation_avatars': None, 'need_points': None, 'nickname': 'Giuseppina Aversa567', 'platform_sync_info': None, 'relative_users': None, 'search_highlight': None, 'sec_uid': 'MS4wLjABAAAAgeSekuZQ-WCbS9NcXIVXO9uFoodPlNLF-FfwUkeZPXeGe47dq-RRKa_ov1NnUExK', 'shield_edit_field_info': None, 'type_label': None, 'uid': '6830525987130786822', 'unique_id': 'giuseppinaaversa', 'user_profile_guide': None, 'user_tags': None, 'white_cover_url': None}, 'user_buried': False, 'user_digged': 0}, {'author_pin': False, 'aweme_id': '7144246488879713542', 'cid': '7144257196086969094', 'collect_stat': 0, 'comment_language': 'it', 'create_time': 1663402035, 'digg_count': 78, 'is_author_digged': False, 'label_list': None, 'no_show': False, 'reply_comment': None, 'reply_comment_total': 9, 'reply_id': '0', 'reply_to_reply_id': '0', 'share_info': {'acl': {'code': 1, 'extra': '{"item_share_acl":"empty item value"}'}, 'desc': "jose luna endo's comment: 😁 per quello voto Conte.", 'title': 'Sarò chiara ancora una volta: non c’è alcuna possibilità che #fratelliditalia  vada al Governo col Partito Democratico. Noi combattiamo la loro egemonia di potere e non saranno di certo le assurde ricostruzioni giornalistiche a farci cambiare idea.', 'url': 'https://m.tiktok.com/v/7144246488879713542.html?_d=e5c561b583004i&comment_author_id=6950877612302468102&language=en&preview_pb=0&share_comment_id=7144257196086969094&share_item_id=7144246488879713542&source=h5_m&u_code=e4kc6ej26a30kk'}, 'status': 1, 'stick_position': 0, 'text': '😁 per quello voto Conte.', 'text_extra': [], 'trans_btn_style': 1, 'user': {'account_labels': None, 'ad_cover_url': None, 'advance_feature_item_order': None, 'advanced_feature_info': None, 'avatar_thumb': {'uri': 'tos-maliva-avt-0068/7063201219346432005', 'url_list': ['https://p77-sign-va.tiktokcdn.com/tos-maliva-avt-0068/7063201219346432005~c5_100x100.jpg?x-expires=1671368400&x-signature=aEctmnzSRLes5Y81xA4Xw2psqaE%3D', ...
# 0 : forza conte 🥰
# 1 : 😁 per quello voto Conte.
# 2 : cara io nn credo a una sola parola. CONTE SEMPRE
# 3 : io voto Conte
# 4 : FORZA M5S
# 5 : Pura verità 👏👏👏👏
# 6 : Sei tu che sei amica degli amici Io non ti voterò mai
# 7 : Bravissima Giorgia, forza avanti così. Se perdiamo te non abbiamo più speranze
# 8 : è tu cosa ai fatto per italiani parole parole
# 9 : forza conte
# 10 : GRANDISSIMA COME SEMPRE SEI LA MIGLIORE DI TUTTI
# 11 : Giorgia premier 🥰🥰🥰🥰
# 12 : Vai avanti così cara Giorgia.
# 13 : Brava 🥰🥰🥰🥰🥰🥰 spero che vinca questa elezioni 💖💖💖💖
# 14 : 😌😅😏Esatto grande Giorgia...
# 15 : grande giorgia🥰🥰
# 16 : loro hanno la paura di perdere, brava come sempre, grande Giorgia 🇮🇹🇮🇹🇮🇹🇮🇹
# 17 : mi fidavo tanto adesso voto Conte
# 18 : Grandeee giorginaaa
# 19 : forza Giorgia
# 20 : Giorgia x sempre
# 21 : Giorgia Premier 🥰
# 22 : sempre Grande GIORGIA🥰
# 23 : sei grandeeeeee
# 24 : daje giorgia siamo tutti con te 💪❤️
# 25 : grande Giorgia 🥰🥰🥰
# 26 : @Giorgia presidente 🥰🥰🥰🥰
# 27 : strillavo anch'io tutti i giorni se prendevo 20.000 euro al mese 🤣🤣🤣
# 28 : noi non vogliamo proprio il PD al governo soprattutto con Letta
#
# Getting next items, cursor value: 30
# 29 : grazie Giorgia🥰🥰🥰
# 30 : forza giorgia
# 31 : NOI VOTIAMO CONTE XCHÉ È CAPACE
# 32 : Bravissima
# 33 : brava Giorgia Meloni sei grande 👍👍👍👍
# 34 : Giorgia per sempre 🥰
# 35 : Forza giorgiaaaaaa
# 36 : Io ti credo .Hai ragione Giorgia.
# 37 : mitica giorgia
# 38 : sempre Giorgia
# 39 : brava Giorgia
# 40 : Dai Giorgia distruggi tutti🥰
# 41 : GIORGIA MELONI ❤ ❤ ❤ ❤ ❤ ❤ ❤
# 42 : Abbasso comte! grande Giorgia!
# 43 : PRIMOOO CIAO GIORGIA
# 44 : @ fantastica Giorgia Premier 🌹
# 45 : Grande Giorgia
# 46 : 🥰grandissima tanta verità.
# 47 : Conte deve andare a casa
# 48 : Grandissima.....ho tanta stima e fiducia in lei.....avanti sempre
# 49 : vai Meloni è il tuo tempo 🥰
# 50 : Forza Giorgia! 🥰🥰🥰
# 51 : che fenomeno
# 52 : una verità reale 👍👏👏
# 53 : chi piazza gli amici e chi i parenti hai ragione
# 54 : grande Giorgia sei la migliore 🥰
# 55 : sei grande vai giorgia🥰🥰🥰🥰🥰🥰
# 56 : Giorgia togli le multe, Vinci Giorgia brava 👏👏👏👏
# 57 : Bellissimo Giorgia Meloni forza
# 58 : 😇
#
# Getting next items, cursor value: 60
#
# 59 : grande Giorgia 🥰🥰🥰🥰🥰
# 60 : ciao!!!
# 61 : Eccellente presidente grazie 🥰
# 62 : giorgia🥰🥰🥰🥰🥰
# 63 : Grande. Avanti così.👍
# 64 : È già..!
# 65 : love you sweetheart
# great lady 👏
# greeting 🙏 to you my ❤️love🥰🥰🥰
# 66 : il vero italiano😁😅
# 67 : parole Sante 👍👍👍❤️❤️❤️
# 68 : Forza Giorgia 🥰👏
# 69 : Sei la numero 1
# 70 : Giorgia forever
# 71 : molto brava sei, meritocratia🥰🌹
# 72 : sei forte vai avanti hanno paura
# 73 : de la Dynamite viva Giorgia MELONI 🌿 bravissimo FÉLICITATIONS
# 74 : brava Giorgia noi siamo con tè sei forte 🥰🥰
# 75 : Grande Giorgia
# 76 : bravissima Giorgia non mollare ❤️
# 77 : vero sono incollato fa tanti anni
# 78 : Verissimo
# 79 : bravaaaaaaaaa🥰
# 80 : forza Giorgia 💪💪💪💪
# 81 : 🥰🥰🥰🥰🥰
# 82 : 🥰🥰
# 83 : esattamente
# 84 : l verita
# 85 : beauty 🥰
# 86 : bravissima
# 87 : grandeeeeeeeeeeeeeeeeeeeeeee
# 88 : forza Giorgia c'è la faremo forza forza
#
#
# #########################################
#
# Processing video 7144023384853171462
# {'alias_comment_deleted': False, 'comments': [{'author_pin': False, 'aweme_id': '7144023384853171462', 'cid': '7147563909825905414', 'collect_stat': 0, 'comment_language': 'it', 'create_time': 1664171958, 'digg_count': 10797, 'is_author_digged': False, 'label_list': None, 'no_show': False, 'reply_comment': None, 'reply_comment_total': 103, 'reply_id': '0', 'reply_to_reply_id': '0', 'share_info': {'acl': {'code': 1, 'extra': '{"item_share_acl":"empty item value"}'}, 'desc': "mariodonofrio03's comment: MI SCUSI MA QUANDO FARÀ LA MARCIA SU ROMA SA NON VORREI PERDERMI L’EVETO… C’È IL RITORNO DELLA SERIE A", 'title': "Chiariamo (ancora una volta) la nostra posizione in merito alla legge sull'aborto. Basta bugie!", 'url': 'https://m.tiktok.com/v/7144023384853171462.html?_d=e5c561b583004i&comment_author_id=7005292388705190917&language=en&preview_pb=0&share_comment_id=7147563909825905414&share_item_id=7144023384853171462&source=h5_m&u_code=e4kc6ej26a30kk'}, 'status': 1, 'stick_position': 0, 'text': 'MI SCUSI MA QUANDO FARÀ LA MARCIA SU ROMA SA NON VORREI PERDERMI L’EVETO… C’È IL RITORNO DELLA SERIE A', 'text_extra': [], 'trans_btn_style': 1, 'user': {'account_labels': None, 'ad_cover_url': None, 'advance_feature_item_order': None, 'advanced_feature_info': None, 'avatar_thumb': {'uri': 'tos-maliva-avt-0068/95a6a19a51c046ce7e9dee740c8e9b94', 'url_list': ['https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/95a6a19a51c046ce7e9dee740c8e9b94~c5_100x100.jpg?x-expires=1671368400&x-signature=sHub4dgTLA7GScOYZsmo8gzMw0c%3D', 'https://p77-sign-va.tiktokcdn.com/tos-maliva-avt-0068/95a6a19a51c046ce7e9dee740c8e9b94~c5_100x100.jpg?x-expires=1671368400&x-signature=Su0F2nTFgL6zmaVnNbuPsF3uGUc%3D', 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/95a6a19a51c046ce7e9dee740c8e9b94~c5_100x100.jpeg?x-expires=1671368400&x-signature=7dR5taenVAXtH7KE3Ybm4xdy1KA%3D']}, 'bold_fields': None, 'can_message_follow_status_list': None, 'can_set_geofencing': None, 'cha_list': None, 'cover_url': None, 'custom_verify': '', 'enterprise_verify_reason': '', 'events': None, 'followers_detail': None, 'geofencing': None, 'homepage_bottom_toast': None, 'item_list': None, 'mutual_relation_avatars': None, 'need_points': None, 'nickname': 'mariodonofrio03', 'platform_sync_info': None, 'relative_users': None, 'search_highlight': None, 'sec_uid': 'MS4wLjABAAAAYZpkt9NUTgJGt9va3oxG6A2LCy1MRpbNh-BL26TfS2wzuj_--ztDeiNOpO8_dWK6', 'shield_edit_field_info': None, 'type_label': None, 'uid': '7005292388705190917', 'unique_id': 'mariodonofrio03', 'user_profile_guide': None, 'user_tags': None, 'white_cover_url': None}, 'user_buried': False, 'user_digged': 0}, {'author_pin': False, 'aweme_id': '7144023384853171462', 'cid': '7147683563185226501', 'collect_stat': 0, 'comment_language': 'en', 'create_time': 1664199788, 'digg_count': 573, 'is_author_digged': False, 'label_list': None, 'no_show': False, 'reply_comment': None, 'reply_comment_total': 3, 'reply_id': '0', 'reply_to_reply_id': '0', 'share_info': {'acl': {'code': 1, 'extra': '{"item_share_acl":"empty item value"}'}, 'desc': 'gio.sara\'s comment: "do you know applicare¿" HAHA💀💀', 'title': "Chiariamo (ancora una volta) la nostra posizione in merito alla legge sull'aborto. Basta bugie!", 'url': 'https://m.tiktok.com/v/7144023384853171462.html?_d=e5c561b583004i&comment_author_id=6843070172690433029&language=en&preview_pb=0&share_comment_id=7147683563185226501&share_item_id=7144023384853171462&source=h5_m&u_code=e4kc6ej26a30kk'}, 'status': 1, 'stick_position': 0, 'text': '"do you know applicare¿" HAHA💀💀', 'text_extra': [], 'trans_btn_style': 0, 'user': {'account_labels': None, 'ad_cover_url': None, 'advance_feature_item_order': None, 'advanced_feature_info': None, 'avatar_thumb': {'uri': 'tos-maliva-avt-0068/a752dd10cd70a191edbd0c60810335c4', 'url_list': ['https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/a752dd10cd70a191edbd0c60810335c4~c5_100x100.jpg?x-expires=1671368400&x-signature=4pwUNSz48nJD9qWrIQQu3WjYyrU%3D', 'https://p77 ...
# 89 : MI SCUSI MA QUANDO FARÀ LA MARCIA SU ROMA SA NON VORREI PERDERMI L’EVETO… C’È IL RITORNO DELLA SERIE A
# 90 : "do you know applicare¿" HAHA💀💀
# 91 : Grande Giorgia! Ti volevo anche chiedere: dici che noi giovani dovremo andare in pensione a 100 anni o per i 90 ci riusciamo?
# 92 : do you know applicare??
# 93 : Su questo ha perfettamente ragione e la 194 in pochi l'hanno letta e ne conoscono ogni suo punto .Giusto apicarla nella sua interezza
# 94 : aiuto
# 95 : lol
# 96 : bro
# 97 : love ❤️
# 98 : Più chiara di così nn può essere stata👏👏👏e chi nn lo capisce nn conosce l italiano🙈🙈🙈, Giorgia avanti nn ditroeggiare🥰🥰🥰🥰🥰🥰🥰🥰
# 99 : spero che se la storia si ripete veramente la marcia su roma sarà tipo un evento per la vincita dell’europa league. forza maggica❤️❤️
# 100 : Non ho capito
# 101 : quando ci aumentate le paghe le pensioni e vi diminuite i vostri 40.000,00€ al mese ,provate voi a vivere con 1500€ al mese benzina luce gas il cibo
# 102 : “do you know APPLICARE?”
# 103 : ma non capiranno mai
# contestano tutto quello che dici facendone un dramma, perché sanno che vincerà la Giorgia
# 104 : aiuto
# 105 : @sf.dmn do you know?
# 106 : su questo è stata brava..ogni mamma ha diritto di aiuti x poter tenersi il bambino!!però sul reddito no perché io lavoro da 3 anni sottopagata e senz
# 107 : fax
# 108 : 😂mamma mia quante volte lo deve spiegare,!! l ha detto mille volte NON vuole ..NON toglie. !!ma come lo deve fare capire
# 109 : Giorgia è il vecchio che si ripresenta.
# se avesse voluto fare quello che propone avrebbe potuto durante le due legislature con Berlusconi..
# o no?😁
# 110 : cara Giorgia,natia del mio stesso quartiere, inizia a dare di nuovo un tricolore a qst Italia che é da troppo tempo un paese grigio e triste
# 111 : do u know?
# 112 : e vorrei capire perché ha messo come altra legge che chi esce si diploma il primo la voto che ti danno con magari uno stipendio basso dobbiamo accetta
# 113 : Brava signora Giorgia speriamo che mantiene tutti i discorsi che a fatto agli Italini .Auguri imbocca al lupo Italiani
# 114 : spero che riuscirai a salvare noi dipendenti ex Alitalia in cassaintegrazione da 5 anni dopo 27 anni di Onorato servizio
# 115 : @/amo/ do you know?🤨
# 116 : Grande Giorgia. Spiega anche x ke persone che non hanno capito che non vuoi togliere il RCD ma REGOLARIZZATO È AUMENTANDOLO A CHI GLI SPETTA xhe...
# 117 : Ciao Giorgia sono molto contenta che hai vinto tu ora ti chiedo farai qualcosa per noi lavoratori interinali dopo 4 anni di lavoro x ASL
# 118 : quindi aiuterà economicamente le famiglie che hanno figli e porterà delle strutture libere dove portare i figli per far lavorare/studiare i genitori?
#
# Getting next items, cursor value: 30
# 119 : una cosa e certa... visibile a tutti...il governo attuale ci ha portato in una situazione molto peggiorativa...per cui ..s ognuno il libero arbitrio
# 120 : Sei number ONE
# 121 : 1: con quale garanzia;
# 2: in che modo;
# 3: se vuole aiutare dando dei soldi, ma da dove li prende sti soldi;
# 4: poi è la stessa persona che detesta⤵️
# 122 : Do you know applicare ?
# 123 : si dovrebbe applicare un mini mo di paga...un obbligo che ogni datore dovrebbe fare..di pagare minimo un tot,per cui si può riuscire a vivere,non stip
# 124 : i know applicare
# 125 : NOOOOON aahah
# 126 : anche perche se tu volessi modificarla non potresti perche non passerebbe in parlamento come "eliminazione di una legge" quindi di cosa stiamo parland
# 127 : @𝕾𝖔𝖋𝖎𝖆 🤍🌼 Do you know applicare ?
# 128 : le tue parole sono sante solo a sentirti si può capire il tuo programe e quello che vuole tutto il popolo italiano bravissima i mie complimenti
# 129 : ma tanto il lavoro dell'altra fazione è e sarà solo screditare qualunque proposta per riprendere la seggiola, mica hanno interesse verso il popolo.
# 130 : Ciao Giorgia vorrei dirti ho un amico che viene dall'Albania e siamo molto legati io e lui e ci conosciamo solo da 3 anni voglio realizzare un sogno
# 131 : Giorgia ho una domanda e richiesta anche..legge 180/78 la lasciamo cosi com è? Quella va bene ? Il lavoro sociale/sanitario può essere considerato
# 132 : Man said do you know
# 133 : faccia qualcosa per la pensione! ho 32 anni e di pensione non ne parlo mai ed è molto triste pensare a questo! vorrei vivermi gli ultimi anni in pace
# 134 : Giorgia sei fra le più stressate d 'Italia. ..e purtroppo con la nazione come è stata ridotta ...hai da fare miracoli. .ma credo in te❤❤❤
# 135 : do you know?!?!?!
# 136 : cara Giorgia io devo lavorare fino 67 anni x andare in pensione..faccio la bidella e non so se riesco fino a 67 anni
# 137 : sweetheart you are the best 👌 l love ❤️you sooooo much
# Jezus is with you 🙏
# greeting
# 138 : Signora Giorgia Meloni io l'ho votata perché la reputo una Donna determinata,il più bel regalo di Natale che può fare agli italiani no al Mes
# 139 : 🥰🥰🥰🥰🥰🥰🥰🥰🥰
# 140 : 😍😍😍😍
# 141 : Siete tutti bravi a parole ma alla fine in sostanza noi non ci fidiamo più delle chiacchiere di nessuno .Non c’è bisogno divotare una legge per farlo
# 142 : 🥰🥰🥰🥰🥰🥰
# 143 : ❤️❤️❤️
# 144 : 🥰🥰🥰
# 145 : 😏
# 146 : 🥰🥰
# 147 : i am
#
# Getting next items, cursor value: 60
#
# 148 : 🥰🥰🥰🥰🥰🥰🥰🥰
# 149 : 🤔🤔🤔
# 150 : 🥰🥰🥰🥰
# 151 : ma può fare il miracolo questo governo dopo che 8 anni i precedenti governi hanno soddisfatto solo i loro interessi?È difficile eliminare il marcio
# 152 : Do you know applicare ?
# 153 : 💋
# 154 : 🥰🥰🥰
# 155 : ciao
# 156 : 💞💕💖❤❤❤💘
# 157 : @🥰🥰
# 158 : certo e nessuno parla di abolire le pensione a vita.e stipendi di acere yn stipendio e no vederecla politica come fonte di arricchimento personale di
# 159 : 🥰🥰🥰💘💘💘🥰🥰🥰
# 160 : 🥰🥰🥰🥰🥰🥰
# 161 : 🥰🥰🥰🥰🥰
# 162 : 🥰
# 163 : 🥰🥰🥰
# 164 : 🥰🥰🥰🥰🥰
# 165 : do you know😂😂
# 166 : 🥰🥰🥰🥰
# 167 : 🥰🥰🥰🥰
# 168 : 🥰🥰🥰🥰
# 169 : Purtroppo pur di andarle contro stanno stravolgendo tutte le sue parole....non è stata una campagna elettorale seria! Forse è la paura!!?
# 170 : aiuto
# 171 : sono anni che dice sempre la stessa cosa davanti alle telecamere ma da seduta nel parlamento vota sempre leggi che vanno contro il +deboli
# 172 : AIUTO
# 173 : votiamo Conte
# 174 : Donna con il coraggio da vendere! Coloro che si alzano la mattina e voglio fare politica,ascoltate colei che spiega quello che vuole fare..poi parlate
# 175 : finalmente una donna con gli attributi al governo auguri signora Giorgia Meloni che dio la benedica e l'aiuti contro tutti i vostri nemici....
# 176 : Io la voterà perché ritengo che anche lei debba avere l'opportunità di governare una Italia ormai allo sfacelo. Forse una donna potrebbe riuscirci.

# %%
print("json files acquired:",len(result))

#after appending all responses to result list, dump them into a single json file
i=0
final_json = "["
for i,elem in enumerate(result): #for each json in the list
    
    #parse json into a string and append it to final_json
    str_elem = json.dumps(elem)
    final_json += str_elem
    
    if i < len(result)-1:  #if it's not last json, append ','
        final_json+=","
    
final_json+="]" #end of file

with open(output_file, "w") as outfile:
    outfile.write(final_json)
# Out:
# json files acquired: 2

# %%
#reading a json file and outputting just the comments

with open(output_file) as infile:
    # returns JSON object as 
    # a dictionary
    data = json.load(infile)

    # Iterating through the json
    # list
    i=0
    for elem in data:
        for comment in elem['comments']:
            comment_text = comment['text']
            print(i,":",comment_text)
            i+=1
# Out:
# 0 : forza conte 🥰
# 1 : 😁 per quello voto Conte.
# 2 : cara io nn credo a una sola parola. CONTE SEMPRE
# 3 : io voto Conte
# 4 : FORZA M5S
# 5 : Pura verità 👏👏👏👏
# 6 : Sei tu che sei amica degli amici Io non ti voterò mai
# 7 : Bravissima Giorgia, forza avanti così. Se perdiamo te non abbiamo più speranze
# 8 : è tu cosa ai fatto per italiani parole parole
# 9 : forza conte
# 10 : GRANDISSIMA COME SEMPRE SEI LA MIGLIORE DI TUTTI
# 11 : Giorgia premier 🥰🥰🥰🥰
# 12 : Vai avanti così cara Giorgia.
# 13 : Brava 🥰🥰🥰🥰🥰🥰 spero che vinca questa elezioni 💖💖💖💖
# 14 : 😌😅😏Esatto grande Giorgia...
# 15 : grande giorgia🥰🥰
# 16 : loro hanno la paura di perdere, brava come sempre, grande Giorgia 🇮🇹🇮🇹🇮🇹🇮🇹
# 17 : mi fidavo tanto adesso voto Conte
# 18 : Grandeee giorginaaa
# 19 : forza Giorgia
# 20 : Giorgia x sempre
# 21 : Giorgia Premier 🥰
# 22 : sempre Grande GIORGIA🥰
# 23 : sei grandeeeeee
# 24 : daje giorgia siamo tutti con te 💪❤️
# 25 : grande Giorgia 🥰🥰🥰
# 26 : @Giorgia presidente 🥰🥰🥰🥰
# 27 : strillavo anch'io tutti i giorni se prendevo 20.000 euro al mese 🤣🤣🤣
# 28 : noi non vogliamo proprio il PD al governo soprattutto con Letta
# 29 : MI SCUSI MA QUANDO FARÀ LA MARCIA SU ROMA SA NON VORREI PERDERMI L’EVETO… C’È IL RITORNO DELLA SERIE A
# 30 : "do you know applicare¿" HAHA💀💀
# 31 : Grande Giorgia! Ti volevo anche chiedere: dici che noi giovani dovremo andare in pensione a 100 anni o per i 90 ci riusciamo?
# 32 : do you know applicare??
# 33 : Su questo ha perfettamente ragione e la 194 in pochi l'hanno letta e ne conoscono ogni suo punto .Giusto apicarla nella sua interezza
# 34 : aiuto
# 35 : lol
# 36 : bro
# 37 : love ❤️
# 38 : Più chiara di così nn può essere stata👏👏👏e chi nn lo capisce nn conosce l italiano🙈🙈🙈, Giorgia avanti nn ditroeggiare🥰🥰🥰🥰🥰🥰🥰🥰
# 39 : spero che se la storia si ripete veramente la marcia su roma sarà tipo un evento per la vincita dell’europa league. forza maggica❤️❤️
# 40 : Non ho capito
# 41 : quando ci aumentate le paghe le pensioni e vi diminuite i vostri 40.000,00€ al mese ,provate voi a vivere con 1500€ al mese benzina luce gas il cibo
# 42 : “do you know APPLICARE?”
# 43 : ma non capiranno mai
# contestano tutto quello che dici facendone un dramma, perché sanno che vincerà la Giorgia
# 44 : aiuto
# 45 : @sf.dmn do you know?
# 46 : su questo è stata brava..ogni mamma ha diritto di aiuti x poter tenersi il bambino!!però sul reddito no perché io lavoro da 3 anni sottopagata e senz
# 47 : fax
# 48 : 😂mamma mia quante volte lo deve spiegare,!! l ha detto mille volte NON vuole ..NON toglie. !!ma come lo deve fare capire
# 49 : Giorgia è il vecchio che si ripresenta.
# se avesse voluto fare quello che propone avrebbe potuto durante le due legislature con Berlusconi..
# o no?😁
# 50 : cara Giorgia,natia del mio stesso quartiere, inizia a dare di nuovo un tricolore a qst Italia che é da troppo tempo un paese grigio e triste
# 51 : do u know?
# 52 : e vorrei capire perché ha messo come altra legge che chi esce si diploma il primo la voto che ti danno con magari uno stipendio basso dobbiamo accetta
# 53 : Brava signora Giorgia speriamo che mantiene tutti i discorsi che a fatto agli Italini .Auguri imbocca al lupo Italiani
# 54 : spero che riuscirai a salvare noi dipendenti ex Alitalia in cassaintegrazione da 5 anni dopo 27 anni di Onorato servizio
# 55 : @/amo/ do you know?🤨
# 56 : Grande Giorgia. Spiega anche x ke persone che non hanno capito che non vuoi togliere il RCD ma REGOLARIZZATO È AUMENTANDOLO A CHI GLI SPETTA xhe...
# 57 : Ciao Giorgia sono molto contenta che hai vinto tu ora ti chiedo farai qualcosa per noi lavoratori interinali dopo 4 anni di lavoro x ASL
# 58 : quindi aiuterà economicamente le famiglie che hanno figli e porterà delle strutture libere dove portare i figli per far lavorare/studiare i genitori?
